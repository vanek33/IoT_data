# %% [markdown]
# # Обзор наборов данных для устройств интернета вещей (IoT)
# Головачев Иван. МИЭМ НИУ ВШЭ
# ## Содержание
# 1. CityPulse Dataset Collection
# 2.

# %%
import pandas as pd
import os

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## CityPulse Dataset Collection
# Ссылка
# http://iot.ee.surrey.ac.uk:8080/datasets.html
# ### 1. Vehicle Traffic
# #### Описание
# Набор построен на основе данных о движении ТС между двумя пунктами
# #### Загрузка мета данных

# %%
path_meta = 'D:/HSE/IoT/DataSets/Vehicle_traffic'
city_meta_data = pd.read_csv(os.path.join(path_meta, 'trafficMetaData.csv'), low_memory=False)
city_meta_data.head()
# Out:
#      POINT_1_STREET  DURATION_IN_SEC  POINT_1_NAME POINT_1_CITY  POINT_2_NAME  \
# 0         Søftenvej               77          4364       Aarhus          4349
# 1          Grenåvej               65          4582      Risskov          4581
# 2    Skanderborgvej               84          3987       Aarhus          2651
# 3          Grenåvej               55          4572      Risskov          4581
# 4  Holmstrupgårdvej               91          4337       Aarhus          4336
#
#    POINT_2_LNG    POINT_2_STREET  NDT_IN_KMH  POINT_2_POSTAL_CODE  \
# 0    10.161038         Søftenvej          70                 8200
# 1    10.219086          Grenåvej          44                 8240
# 2    10.157659      Viby Ringvej          35                 8260
# 3    10.218878          Grenåvej          53                 8240
# 4    10.120842  Holmstrupgårdvej          40                 8210
#
#   POINT_2_COUNTRY POINT_1_STREET_NUMBER ORGANISATION  POINT_1_LAT  \
# 0         Denmark                     0         COWI    56.214979
# 1         Denmark                   126         COWI    56.186546
# 2         Denmark                   168         COWI    56.131054
# 3         Denmark                     0         COWI    56.197744
# 4         Denmark                    28         COWI    56.169455
#
#    POINT_2_LAT  POINT_1_POSTAL_CODE POINT_2_STREET_NUMBER POINT_2_CITY  extID  \
# 0    56.208520                 8200                     0       Aarhus    179
# 1    56.193692                 8240                   126      Risskov    194
# 2    56.132032                 8260                   168       Aarhus    324
# 3    56.193711                 8240                     0      Risskov    383
# 4    56.178403                 8220                   150       Aarhus    436
#
#     ROAD_TYPE  POINT_1_LNG  REPORT_ID POINT_1_COUNTRY  DISTANCE_IN_METERS  \
# 0  MAJOR_ROAD    10.139696     158895         Denmark                1505
# 1  MAJOR_ROAD    10.218304     178600         Denmark                 797
# 2  MAJOR_ROAD    10.166163     187509         Denmark                 823
# 3  MAJOR_ROAD    10.228594     190744         Denmark                 813
# 4  MAJOR_ROAD    10.119669     195041         Denmark                1015
#
#              REPORT_NAME  RBA_ID   _id
# 0  AAR_BT_0020 4364 4349  161062  1586
# 1  AAR_BT_0101 4582 4581  178660  1601
# 2  AAR_BT_0231 3987 2651  189702  1731
# 3  AAR_BT_0291 4572 4581  192392  1790
# 4  AAR_BT_0356 4337 4336  229156  1843

# %% [markdown]
# #### Загрузка данных

# %%
path_001 = 'D:/HSE/IoT/DataSets/Vehicle_traffic/traffic_feb_june'
city_data = pd.read_csv(os.path.join(path_001, 'trafficData158324.csv'), low_memory=False)
city_data.head()
# Out:
#   status  avgMeasuredTime  avgSpeed  extID  medianMeasuredTime  \
# 0     OK               66        56    668                  66
# 1     OK               69        53    668                  69
# 2     OK               69        53    668                  69
# 3     OK               70        52    668                  70
# 4     OK               64        57    668                  64
#
#              TIMESTAMP  vehicleCount     _id  REPORT_ID
# 0  2014-02-13T11:30:00             7  190000     158324
# 1  2014-02-13T11:35:00             5  190449     158324
# 2  2014-02-13T11:40:00             6  190898     158324
# 3  2014-02-13T11:45:00             3  191347     158324
# 4  2014-02-13T11:50:00             6  191796     158324

# %% [markdown]
# #### Форма данных

# %%
city_data.shape
# Out:
# (32075, 9)

# %% [markdown]
# #### Список переменных

# %%
city_data.columns
# Out:
# Index(['status', 'avgMeasuredTime', 'avgSpeed', 'extID', 'medianMeasuredTime',
#        'TIMESTAMP', 'vehicleCount', '_id', 'REPORT_ID'],
#       dtype='object')

# %% [markdown]
# #### Описание переменных
# status				-	статус датчика (?)
# avgMeasuredTime		-	среднее измеренное время (?)
# avgSpeed			-	средняя скорость движения ТС
# extID				-
# medianMeasuredTime	-
# TIMESTAMP			-
# vehicleCount		-
# _id					-
# REPORT_ID			-
